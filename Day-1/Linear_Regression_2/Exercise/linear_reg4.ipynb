# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from sklearn import linear_model 
# !pip install word2number
from word2number import w2n

# %%
df = pd.read_csv("hiring.csv")
df
# Out:
#   experience  test_score  interview_score  salary
# 0        NaN         8.0                9   50000
# 1        NaN         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000
# 5      three         7.0               10   62000
# 6        ten         NaN                7   72000
# 7     eleven         7.0                8   80000

# %%
df.test_score = df.test_score.fillna(df.test_score.median())

# %%
df.experience = df.experience.fillna(0)

# %%
df[["experience"]]
# Out:
#   experience
# 0          0
# 1          0
# 2       five
# 3        two
# 4      seven
# 5      three
# 6        ten
# 7     eleven

# %%
for i in range(2,8):
    df.loc[i,'experience'] = w2n.word_to_num(df.loc[i,'experience'])

# %%
df
# Out:
#   experience  test_score  interview_score  salary
# 0          0         8.0                9   50000
# 1          0         8.0                6   45000
# 2          5         6.0                7   60000
# 3          2        10.0               10   65000
# 4          7         9.0                6   70000
# 5          3         7.0               10   62000
# 6         10         8.0                7   72000
# 7         11         7.0                8   80000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['experience','test_score','interview_score']],df.salary)
# Out:
# LinearRegression()

# %%
new_data = pd.DataFrame({'experience':[2],'test_score':[9],'interview_score':[6]}) 
reg.predict(new_data).round()
# Out:
# array([53206.])

# %%
new_data = pd.DataFrame({'experience':[12],'test_score':[10],'interview_score':[10]}) 
reg.predict(new_data).round()
# Out:
# array([92002.])

# %%
add_data = pd.DataFrame({'experience':[12],'test_score':[10],'interview_score':[10],'salary':[53206]}) 
df = pd.concat([df, add_data], ignore_index=True)

# %%
add_data = pd.DataFrame({'experience':[2],'test_score':[9],'interview_score':[6],'salary':[92002]}) 
df = pd.concat([df, add_data], ignore_index=True)

# %%
df
# Out:
#   experience  test_score  interview_score  salary
# 0          0         8.0                9   50000
# 1          0         8.0                6   45000
# 2          5         6.0                7   60000
# 3          2        10.0               10   65000
# 4          7         9.0                6   70000
# 5          3         7.0               10   62000
# 6         10         8.0                7   72000
# 7         11         7.0                8   80000
# 8         12        10.0               10   53206
# 9          2         9.0                6   92002

# %%
df.to_csv("Prediction.csv",index=False)

# %%
#plt.figure(figsize=(10, 6))
#plt.plot(df['experience'], df['salary'], marker='o', color='blue', label='Experience vs Salary')
#plt.title('Experience vs Salary', fontsize=14)
#plt.xlabel('Experience (Years)', fontsize=12)
#plt.ylabel('Salary (USD)', fontsize=12)
#plt.grid(True)
#plt.legend()
#plt.show()
